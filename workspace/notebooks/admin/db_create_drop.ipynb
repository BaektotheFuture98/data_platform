# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Jupyter_Seonmin").getOrCreate()

spark
# Out:
# Picked up JAVA_TOOL_OPTIONS: -Duser.home=/home/iceberg -Djava.util.prefs.userRoot=/home/iceberg/.java/.userPrefs
# Picked up JAVA_TOOL_OPTIONS: -Duser.home=/home/iceberg -Djava.util.prefs.userRoot=/home/iceberg/.java/.userPrefs
# WARNING: Using incubator modules: jdk.incubator.vector
# 26/07/11 16:33:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://c769d7062684:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Jupyter_Seonmin</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.sql("create database if not exists bronze")
spark.sql("create database if not exists silver")
spark.sql("create database if not exists gold")
# Out:
# 26/07/11 16:39:45 INFO AuthManagers: Loading AuthManager implementation: org.apache.iceberg.rest.auth.NoopAuthManager
# 26/07/11 16:39:45 INFO CatalogUtil: Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO
# DataFrame[]

# %%
spark.sql("show databases")
# Out:
# DataFrame[namespace: string]

# %%
spark.sql("show databases").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |      nyc|
# |   bronze|
# |     gold|
# |   silver|
# +---------+

# %%
spark.sql("SHOW TABLES IN nyc").show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |      nyc|    taxis|      false|
# +---------+---------+-----------+

# %%
spark.sql("DROP TABLE nyc.taxis")
# Out:
# DataFrame[]

# %%
spark.sql("DROP DATABASE nyc")
# Out:
# DataFrame[]

# %%
spark.sql("show databases").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |   bronze|
# |     gold|
# |   silver|
# +---------+

# %%
spark.sql("DROP DATABASE bronze")
spark.sql("DROP DATABASE silver")
spark.sql("DROP DATABASE gold")
# Out:
# DataFrame[]

# %%
spark.sql("show databases").show()
# Out:
# +---------+
# |namespace|
# +---------+
# +---------+

# %%
spark.stop()
